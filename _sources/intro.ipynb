# %% [markdown]
# # Welcome to Yasmin's Jupyter Book
# ## NIM : 230411100186
#
# Ini adalah Jupiter Book Yasmin yang berisi tentang Materi Komputasi Aljabar Linier Semester 2
#
# Semoga materi ini bermanfaat bagi pembaca.
#
# Kunjungi link berikut untuk dokumentasi Jupyter notebook [the Jupyter Book documentation](https://jupyterbook.org) untuk informasi lebih lanjut.
#
# Check out the content pages bundled with this sample book to see more.
#
# ```{tableofcontents}
# ```
